# %% [markdown]
# # SH-wave modelling — Virieux (1984) quarter-plane example
#
# Reproduces the expanding-wavefield surface plots from Virieux (1984), Figure 3,
# using the velocity-stress staggered-grid FD scheme on a constant homogeneous medium.
#
# **Physical parameters (Table 1 of the paper)**
#
# | Parameter | Value |
# |-----------|-------|
# | Shear velocity | 3 000 m/s |
# | Grid spacing *dx* | 30 m |
# | Grid size | 60 × 60 nodes |
# | Source position | (615, 615) m |
# | Source half-wavelength | 300 m  →  f₀ ≈ 5 Hz |

# %%
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # noqa – required for projection='3d'

from devito import TimeFunction, NODE, configuration, print_defaults

from examples.seismic import demo_model, AcquisitionGeometry
from examples.seismic.sh.operators import ForwardOperator
from devito import configuration, set_log_level
# configuration['log-level']='CRITICAL'
# configuration['profiling']='advisor'
configuration['platform'] = 'nvidiaX'
configuration['compiler'] = 'pgcc'
configuration['language'] = 'openacc'

print_defaults()
# Out:
# DEVITO_ARCH: {'custom': <class 'devito.arch.compiler.CustomCompiler'>, 'gnu': <class 'devito.arch.compiler.GNUCompiler'>, 'gcc': <class 'devito.arch.compiler.GNUCompiler'>, 'arm': <class 'devito.arch.compiler.ArmCompiler'>, 'clang': <class 'devito.arch.compiler.ClangCompiler'>, 'cray': <class 'devito.arch.compiler.CrayCompiler'>, 'aomp': <class 'devito.arch.compiler.AOMPCompiler'>, 'amdclang': <class 'devito.arch.compiler.AOMPCompiler'>, 'hip': <class 'devito.arch.compiler.HipCompiler'>, 'pgcc': <class 'devito.arch.compiler.PGICompiler'>, 'pgi': <class 'devito.arch.compiler.PGICompiler'>, 'nvc': <class 'devito.arch.compiler.NvidiaCompiler'>, 'nvc++': <class 'devito.arch.compiler.NvidiaCompiler'>, 'nvidia': <class 'devito.arch.compiler.NvidiaCompiler'>, 'cuda': <class 'devito.arch.compiler.CudaCompiler'>, 'nvcc': <class 'devito.arch.compiler.CudaCompiler'>, 'osx': <class 'devito.arch.compiler.ClangCompiler'>, 'intel': <class 'devito.arch.compiler.OneapiCompiler'>, 'icx': <class 'devito.arch.compiler.OneapiCompiler'>, 'icpx': <class 'devito.arch.compiler.OneapiCompiler'>, 'sycl': <class 'devito.arch.compiler.SyclCompiler'>, 'icc': <class 'devito.arch.compiler.IntelCompiler'>, 'icpc': <class 'devito.arch.compiler.IntelCompiler'>, 'intel-knl': <class 'devito.arch.compiler.IntelKNLCompiler'>, 'knl': <class 'devito.arch.compiler.IntelKNLCompiler'>, 'dpcpp': <class 'devito.arch.compiler.DPCPPCompiler'>}. Default: custom
# DEVITO_PLATFORM: ['cpu64', 'cpu64-dummy', 'intel64', 'snb', 'ivb', 'hsw', 'bdw', 'knl', 'knl7210', 'skx', 'klx', 'clx', 'clk', 'spr', 'arm', 'graviton2', 'graviton3', 'graviton4', 'm1', 'm2', 'm3', 'cortex', 'cortexa76', 'grace', 'amd', 'power8', 'power9', 'gpu', 'nvidiaX', 'volta', 'ampere', 'hopper', 'blackwell', 'amdgpuX', 'intelgpuX', 'pvc', 'intelgpuMAX', 'max1100', 'max1550']. Default: cpu64
# DEVITO_PROFILING: ['basic', 'basic1', 'basic2', 'advanced', 'advanced1', 'advanced2', 'advisor']. Default: basic
# DEVITO_DEVELOP: [False, True]. Default: False
# DEVITO_OPT: ['noop', 'advanced', 'advanced-fsg', ('noop', 'C'), ('noop', 'CXX'), ('noop', 'openmp'), ('noop', 'Copenmp'), ('noop', 'CXXopenmp'), ('noop', 'openacc'), ('noop', 'cuda'), ('noop', 'hip'), ('noop', 'sycl'), ('advanced', 'C'), ('advanced', 'CXX'), ('advanced', 'openmp'), ('advanced', 'Copenmp'), ('advanced', 'CXXopenmp'), ('advanced', 'openacc'), ('advanced', 'cuda'), ('advanced', 'hip'), ('advanced', 'sycl'), ('advanced-fsg', 'C'), ('advanced-fsg', 'CXX'), ('advanced-fsg', 'openmp'), ('advanced-fsg', 'Copenmp'), ('advanced-fsg', 'CXXopenmp'), ('advanced-fsg', 'openacc'), ('advanced-fsg', 'cuda'), ('advanced-fsg', 'hip'), ('advanced-fsg', 'sycl')]. Default: advanced
# DEVITO_MPI: [0, 1, 'basic', 'diag', 'diag2', 'overlap', 'overlap2', 'full', 'dual']. Default: 0
# DEVITO_TOPOLOGY: [None, 'x', 'y', 'z', 'xy']. Default: None
# DEVITO_DEVICEID: None. Default: -1
# DEVITO_LANGUAGE: [0, 1, 'C', 'CXX', 'openmp', 'Copenmp', 'CXXopenmp', 'openacc', 'cuda', 'hip', 'sycl']. Default: C
# DEVITO_AUTOTUNING: ['off', 'basic', 'aggressive', 'max', ['off', 'preemptive'], ['off', 'destructive'], ['off', 'runtime'], ['basic', 'preemptive'], ['basic', 'destructive'], ['basic', 'runtime'], ['aggressive', 'preemptive'], ['aggressive', 'destructive'], ['aggressive', 'runtime'], ['max', 'preemptive'], ['max', 'destructive'], ['max', 'runtime']]. Default: off
# DEVITO_LOGGING: ['DEBUG', 'PERF', 'INFO', 'WARNING', 'ERROR', 'CRITICAL']. Default: INFO
# DEVITO_FIRST_TOUCH: [0, 1]. Default: 0
# DEVITO_JIT_BACKDOOR: [0, 1]. Default: 0
# DEVITO_IGNORE_UNKNOWN_PARAMS: [0, 1]. Default: 0
# DEVITO_SAFE_MATH: [0, 1]. Default: 0

# %% [markdown]
# ## 1. Model

# %%
shape       = (100, 60)   # grid nodes (physical domain)
spacing     = (30., 30.) # [m]
nbl         = 150         # absorbing boundary layers
space_order = 6          # 2nd-order FD as in Virieux (1984)

model = demo_model(
    'layers-sh',
    shape   = shape,
    spacing = spacing,
    nbl     = nbl,
    space_order = space_order,
)
print(f'mu           = {model.mu}  (shear modulus)')
print(f'b            = {model.b}   (buoyancy = 1/density)')
print(f'critical_dt  = {model.critical_dt:.3f} ms')
print(f'domain size  = {model.domain_size} m')
# Out:
# pgc++-Warning- The -gpu=pinned option is deprecated; please use -gpu=mem:separate:pinnedalloc instead
# Operator `initdamp` ran in 0.29 s
# pgc++-Warning- The -gpu=pinned option is deprecated; please use -gpu=mem:separate:pinnedalloc instead
# pgc++-Warning- The -gpu=pinned option is deprecated; please use -gpu=mem:separate:pinnedalloc instead
# mu           = mu(x, y)  (shear modulus)
# b            = b(x, y)   (buoyancy = 1/density)
# critical_dt  = 3.003 ms
# domain size  = (np.float32(2970.0), np.float32(1770.0)) m

# %% [markdown]
# ## 2. Geometry and time axis

# %%
t0, tn = 0., 750.  # [ms]  (0 → 0.75 s)
f0     = 0.005     # [kHz] = 5 Hz  →  half-wavelength = 3 000 / (2×5) = 300 m

# geometry.src is a property that creates a new SparseTimeFunction from
# src_positions on every access, so coordinates must be fixed at construction.
src_positions = np.array([[1515., 45.]], dtype=np.float32)  # Virieux (1984), Table 1
rec_positions = np.array([[255., 615.]], dtype=np.float32)  # observer position

geometry = AcquisitionGeometry(
    model, rec_positions, src_positions,
    t0=t0, tn=tn, src_type='Ricker', f0=f0,
)

dt = geometry.dt
print(f'Source at : {geometry.src_positions[0]} m')
print(f'dt        : {dt:.3f} ms   nt = {geometry.nt}')
# Out:
# Source at : [1515.   45.] m
# dt        : 3.003 ms   nt = 251

# %% [markdown]
# ## 3. Build operator and wavefield buffers

# %%
op = ForwardOperator(model, geometry, space_order=space_order)

x, z = model.grid.dimensions

# Wavefield buffers (time_order=1 → 2-slot ring buffer)
v      = TimeFunction(name='v',      grid=model.grid, space_order=space_order,
                      time_order=1, staggered=NODE)
tau_xy = TimeFunction(name='tau_xy', grid=model.grid, space_order=space_order,
                      time_order=1, staggered=(x,))
tau_zy = TimeFunction(name='tau_zy', grid=model.grid, space_order=space_order,
                      time_order=1, staggered=(z,))
rec = geometry.new_rec(name='rec')

# %% [markdown]
# ## 4. Run in segments — capture v at each snapshot time

# %%
snap_ms     = [250., 500., 750.]               # snapshot times [ms]
snap_steps  = [int(t / dt) for t in snap_ms]  # corresponding time-loop indices

print('Snapshot steps:', snap_steps)

snapshots = []
prev = 0

for step in snap_steps:
    op.apply(
        v=v, tau_xy=tau_xy, tau_zy=tau_zy,
        src=geometry.src, rec=rec,
        time_m=prev, time_M=step,
        dt=dt,
        **model.physical_params(),
    )
    # With time_order=1, v.forward at iteration k is stored at slot (k+1)%2.
    # After running to time_M=step the most recent v is at slot (step+1)%2.
    slot = (step + 1) % 2
    data = v.data[slot, nbl:-nbl, nbl:-nbl].copy()
    snapshots.append(data)
    prev = step + 1
    print(f't ≈ {step*dt:.0f} ms  |v|_max = {np.abs(data).max():.4f}')
# Out:
# Snapshot steps: [83, 166, 249]
# pgc++-Warning- The -gpu=pinned option is deprecated; please use -gpu=mem:separate:pinnedalloc instead
# Operator `ForwardSH` ran in 0.01 s
# Operator `ForwardSH` ran in 0.01 s
# Operator `ForwardSH` ran in 0.01 s
# t ≈ 249 ms  |v|_max = 1.6960
# t ≈ 498 ms  |v|_max = 0.8152
# t ≈ 748 ms  |v|_max = 0.6806

# %% [markdown]
# ## 5. Three-panel 3-D surface plot

# %%
from matplotlib import cm

snap_titles = ['0.25 sec', '0.50 sec', '0.75 sec']

# Physical-domain coordinate grids [m]
x_coord = np.arange(shape[0]) * spacing[0]
z_coord = np.arange(shape[1]) * spacing[1]
X, Z = np.meshgrid(x_coord, z_coord, indexing='ij')

color_data = model.mu.data[nbl:-nbl, nbl:-nbl]
norm = plt.Normalize(color_data.min(), color_data.max())
colors = cm.spring(norm(color_data))

fig = plt.figure(figsize=(18, 6), facecolor='white')

for n, (data, title) in enumerate(zip(snapshots, snap_titles)):
    ax = fig.add_subplot(1, 3, n + 1, projection='3d')

    # Normalise per-frame so the wavefront is visible at each time
    vmax = np.max(np.abs(data))
    if vmax > 0:
        data = -data / vmax

    ax.plot_surface(
        X, Z, data* 3e2,
        rstride=1, cstride=1,
        linewidth=1,
        alpha=0.5,
        facecolors=colors, shade=False,
        # edgecolors='r',
    )
    ax.plot_surface(
        X, Z, data* 3e2,
        rstride=1, cstride=1,
        linewidth=0.3, edgecolors='w',
        # color='white',
        alpha=0.75
        # shade=False,
    )
    ax.set_title(title, fontsize=13, pad=8)
    ax.view_init(elev=30, azim=225)
    ax.set_axis_off()
    ax.set_aspect('equal')

plt.tight_layout()
plt.show()

# %%
print(op)
# Out:
# /* Devito generated code for Operator `ForwardSH` */
#
# #define _POSIX_C_SOURCE 200809L
# #define START(S) struct timeval start_ ## S , end_ ## S ; gettimeofday(&start_ ## S , NULL);
# #define STOP(S,T) gettimeofday(&end_ ## S, NULL); T->S += (double)(end_ ## S .tv_sec-start_ ## S.tv_sec)+(double)(end_ ## S .tv_usec-start_ ## S .tv_usec)/1000000;
# #define SAFEINV(a, b) (((a) < 9.999999960041972e-13F || ((float)b) < 9.999999960041972e-13F) ? (0.0F) : ((1.0F) / (a)))
#
# #include <cstdlib>
# #include <cmath>
# #include "sys/time.h"
# #include "openacc.h"
#
# struct dataobj
# {
#   void *__restrict data;
#   int * size;
#   unsigned long nbytes;
#   unsigned long * npsize;
#   unsigned long * dsize;
#   int * hsize;
#   int * hofs;
#   int * oofs;
#   void * dmap;
# } ;
#
# struct profiler
# {
#   double section0;
#   double section1;
#   double section2;
# } ;
#
# extern "C" int ForwardSH(struct dataobj *__restrict b_vec, struct dataobj *__restrict damp_vec, struct dataobj *__restrict mu_vec, struct dataobj *__restrict rec_vec, struct dataobj *__restrict rec_coords_vec, struct dataobj *__restrict src_vec, struct dataobj *__restrict src_coords_vec, struct dataobj *__restrict tau_xy_vec, struct dataobj *__restrict tau_zy_vec, struct dataobj *__restrict v_vec, const int x_M, const int x_m, const int y_M, const int y_m, const float dt, const float o_x, const float o_y, const int p_rec_M, const int p_rec_m, const int p_src_M, const int p_src_m, const int time_M, const int time_m, const int deviceid, const int devicerm, struct profiler * timers);
#
#
# int ForwardSH(struct dataobj *__restrict b_vec, struct dataobj *__restrict damp_vec, struct dataobj *__restrict mu_vec, struct dataobj *__restrict rec_vec, struct dataobj *__restrict rec_coords_vec, struct dataobj *__restrict src_vec, struct dataobj *__restrict src_coords_vec, struct dataobj *__restrict tau_xy_vec, struct dataobj *__restrict tau_zy_vec, struct dataobj *__restrict v_vec, const int x_M, const int x_m, const int y_M, const int y_m, const float dt, const float o_x, const float o_y, const int p_rec_M, const int p_rec_m, const int p_src_M, const int p_src_m, const int time_M, const int time_m, const int deviceid, const int devicerm, struct profiler * timers)
# {
#   /* Beginning of OpenACC setup */
#   acc_init(acc_device_nvidia);
#   if (deviceid != -1)
#   {
#     acc_set_device_num(deviceid,acc_device_nvidia);
#   }
#   /* End of OpenACC setup */
#
#   float (*__restrict b)[b_vec->size[1]] __attribute__ ((aligned (64))) = (float (*)[b_vec->size[1]]) b_vec->data;
#   float (*__restrict damp)[damp_vec->size[1]] __attribute__ ((aligned (64))) = (float (*)[damp_vec->size[1]]) damp_vec->data;
#   float (*__restrict mu)[mu_vec->size[1]] __attribute__ ((aligned (64))) = (float (*)[mu_vec->size[1]]) mu_vec->data;
#   float (*__restrict rec)[rec_vec->size[1]] __attribute__ ((aligned (64))) = (float (*)[rec_vec->size[1]]) rec_vec->data;
#   float (*__restrict rec_coords)[rec_coords_vec->size[1]] __attribute__ ((aligned (64))) = (float (*)[rec_coords_vec->size[1]]) rec_coords_vec->data;
#   float (*__restrict src)[src_vec->size[1]] __attribute__ ((aligned (64))) = (float (*)[src_vec->size[1]]) src_vec->data;
#   float (*__restrict src_coords)[src_coords_vec->size[1]] __attribute__ ((aligned (64))) = (float (*)[src_coords_vec->size[1]]) src_coords_vec->data;
#   float (*__restrict tau_xy)[tau_xy_vec->size[1]][tau_xy_vec->size[2]] __attribute__ ((aligned (64))) = (float (*)[tau_xy_vec->size[1]][tau_xy_vec->size[2]]) tau_xy_vec->data;
#   float (*__restrict tau_zy)[tau_zy_vec->size[1]][tau_zy_vec->size[2]] __attribute__ ((aligned (64))) = (float (*)[tau_zy_vec->size[1]][tau_zy_vec->size[2]]) tau_zy_vec->data;
#   float (*__restrict v)[v_vec->size[1]][v_vec->size[2]] __attribute__ ((aligned (64))) = (float (*)[v_vec->size[1]][v_vec->size[2]]) v_vec->data;
#
#   #pragma acc enter data copyin(rec[0:rec_vec->size[0]][0:rec_vec->size[1]])
#   #pragma acc enter data copyin(tau_xy[0:tau_xy_vec->size[0]][0:tau_xy_vec->size[1]][0:tau_xy_vec->size[2]])
#   #pragma acc enter data copyin(tau_zy[0:tau_zy_vec->size[0]][0:tau_zy_vec->size[1]][0:tau_zy_vec->size[2]])
#   #pragma acc enter data copyin(v[0:v_vec->size[0]][0:v_vec->size[1]][0:v_vec->size[2]])
#   #pragma acc enter data copyin(b[0:b_vec->size[0]][0:b_vec->size[1]])
#   #pragma acc enter data copyin(damp[0:damp_vec->size[0]][0:damp_vec->size[1]])
#   #pragma acc enter data copyin(mu[0:mu_vec->size[0]][0:mu_vec->size[1]])
#   #pragma acc enter data copyin(rec_coords[0:rec_coords_vec->size[0]][0:rec_coords_vec->size[1]])
#   #pragma acc enter data copyin(src[0:src_vec->size[0]][0:src_vec->size[1]])
#   #pragma acc enter data copyin(src_coords[0:src_coords_vec->size[0]][0:src_coords_vec->size[1]])
#
#   float r1 = 1.0F/dt;
#   for (int time = time_m, t0 = (time)%(2), t1 = (time + 1)%(2); time <= time_M; time += 1, t0 = (time)%(2), t1 = (time + 1)%(2))
#   {
#     START(section0)
#     #pragma acc parallel loop collapse(2) present(b,damp,tau_xy,tau_zy,v)
#     for (int x = x_m; x <= x_M; x += 1)
#     {
#       for (int y = y_m; y <= y_M; y += 1)
#       {
#         v[t1][x + 6][y + 6] = dt*(r1*v[t0][x + 6][y + 6] + (1.56250008e-4F*(-tau_xy[t0][x + 3][y + 6] + tau_xy[t0][x + 8][y + 6] - tau_zy[t0][x + 6][y + 3] + tau_zy[t0][x + 6][y + 8]) + 2.170139e-3F*(tau_xy[t0][x + 4][y + 6] - tau_xy[t0][x + 7][y + 6] + tau_zy[t0][x + 6][y + 4] - tau_zy[t0][x + 6][y + 7]) + 3.9062502e-2F*(-tau_xy[t0][x + 5][y + 6] + tau_xy[t0][x + 6][y + 6] - tau_zy[t0][x + 6][y + 5] + tau_zy[t0][x + 6][y + 6]))*b[x + 6][y + 6])*damp[x + 6][y + 6];
#       }
#     }
#     #pragma acc parallel loop collapse(2) present(damp,mu,tau_xy,tau_zy,v)
#     for (int x = x_m; x <= x_M; x += 1)
#     {
#       for (int y = y_m; y <= y_M; y += 1)
#       {
#         float r2 = 5.0e-1F/mu[x + 6][y + 6];
#         tau_xy[t1][x + 6][y + 6] = dt*damp[x + 6][y + 6]*(r1*tau_xy[t0][x + 6][y + 6] + (1.56250008e-4F*(-v[t1][x + 4][y + 6] + v[t1][x + 9][y + 6]) + 2.170139e-3F*(v[t1][x + 5][y + 6] - v[t1][x + 8][y + 6]) + 3.9062502e-2F*(-v[t1][x + 6][y + 6] + v[t1][x + 7][y + 6]))*SAFEINV(r2 + 5.0e-1F/mu[x + 7][y + 6], mu[x + 6][y + 6]));
#         tau_zy[t1][x + 6][y + 6] = dt*damp[x + 6][y + 6]*(r1*tau_zy[t0][x + 6][y + 6] + (1.56250008e-4F*(-v[t1][x + 6][y + 4] + v[t1][x + 6][y + 9]) + 2.170139e-3F*(v[t1][x + 6][y + 5] - v[t1][x + 6][y + 8]) + 3.9062502e-2F*(-v[t1][x + 6][y + 6] + v[t1][x + 6][y + 7]))*SAFEINV(r2 + 5.0e-1F/mu[x + 6][y + 7], mu[x + 6][y + 6]));
#       }
#     }
#     STOP(section0,timers)
#
#     START(section1)
#     if (src_vec->size[0]*src_vec->size[1] > 0 && p_src_M - p_src_m + 1 > 0)
#     {
#       #pragma acc parallel loop collapse(3) present(src,src_coords,v)
#       for (int p_src = p_src_m; p_src <= p_src_M; p_src += 1)
#       {
#         for (int rsrcx = 0; rsrcx <= 1; rsrcx += 1)
#         {
#           for (int rsrcy = 0; rsrcy <= 1; rsrcy += 1)
#           {
#             int posx = static_cast<int>(std::floor(3.33333e-2*(-o_x + src_coords[p_src][0])));
#             int posy = static_cast<int>(std::floor(3.33333e-2*(-o_y + src_coords[p_src][1])));
#             float px = 3.33333e-2F*(-o_x + src_coords[p_src][0]) - std::floor(3.33333e-2F*(-o_x + src_coords[p_src][0]));
#             float py = 3.33333e-2F*(-o_y + src_coords[p_src][1]) - std::floor(3.33333e-2F*(-o_y + src_coords[p_src][1]));
#             if (rsrcx + posx >= x_m - 1 && rsrcy + posy >= y_m - 1 && rsrcx + posx <= x_M + 1 && rsrcy + posy <= y_M + 1)
#             {
#               float r0 = dt*(rsrcx*px + (1 - rsrcx)*(1 - px))*(rsrcy*py + (1 - rsrcy)*(1 - py))*src[time][p_src];
#               #pragma acc atomic update
#               v[t1][rsrcx + posx + 6][rsrcy + posy + 6] += r0;
#             }
#           }
#         }
#       }
#     }
#     STOP(section1,timers)
#
#     START(section2)
#     if (rec_vec->size[0]*rec_vec->size[1] > 0 && p_rec_M - p_rec_m + 1 > 0)
#     {
#       #pragma acc parallel loop present(rec,rec_coords,v)
#       for (int p_rec = p_rec_m; p_rec <= p_rec_M; p_rec += 1)
#       {
#         float r5 = 3.33333e-2F*(-o_x + rec_coords[p_rec][0]);
#         float r3 = std::floor(r5);
#         int posx = static_cast<int>(r3);
#         float r6 = 3.33333e-2F*(-o_y + rec_coords[p_rec][1]);
#         float r4 = std::floor(r6);
#         int posy = static_cast<int>(r4);
#         float px = -r3 + r5;
#         float py = -r4 + r6;
#         float sum = 0.0F;
#
#         for (int rrecx = 0; rrecx <= 1; rrecx += 1)
#         {
#           for (int rrecy = 0; rrecy <= 1; rrecy += 1)
#           {
#             if (rrecx + posx >= x_m - 1 && rrecy + posy >= y_m - 1 && rrecx + posx <= x_M + 1 && rrecy + posy <= y_M + 1)
#             {
#               sum += (rrecx*px + (1 - rrecx)*(1 - px))*(rrecy*py + (1 - rrecy)*(1 - py))*v[t0][rrecx + posx + 6][rrecy + posy + 6];
#             }
#           }
#         }
#
#         rec[time][p_rec] = sum;
#       }
#     }
#     STOP(section2,timers)
#   }
#
#   #pragma acc exit data copyout(rec[0:rec_vec->size[0]][0:rec_vec->size[1]])
#   #pragma acc exit data delete(rec[0:rec_vec->size[0]][0:rec_vec->size[1]]) if(devicerm)
#   #pragma acc exit data copyout(tau_xy[0:tau_xy_vec->size[0]][0:tau_xy_vec->size[1]][0:tau_xy_vec->size[2]])
#   #pragma acc exit data delete(tau_xy[0:tau_xy_vec->size[0]][0:tau_xy_vec->size[1]][0:tau_xy_vec->size[2]]) if(devicerm)
#   #pragma acc exit data copyout(tau_zy[0:tau_zy_vec->size[0]][0:tau_zy_vec->size[1]][0:tau_zy_vec->size[2]])
#   #pragma acc exit data delete(tau_zy[0:tau_zy_vec->size[0]][0:tau_zy_vec->size[1]][0:tau_zy_vec->size[2]]) if(devicerm)
#   #pragma acc exit data copyout(v[0:v_vec->size[0]][0:v_vec->size[1]][0:v_vec->size[2]])
#   #pragma acc exit data delete(v[0:v_vec->size[0]][0:v_vec->size[1]][0:v_vec->size[2]]) if(devicerm)
#   #pragma acc exit data delete(b[0:b_vec->size[0]][0:b_vec->size[1]]) if(devicerm)
#   #pragma acc exit data delete(damp[0:damp_vec->size[0]][0:damp_vec->size[1]]) if(devicerm)
#   #pragma acc exit data delete(mu[0:mu_vec->size[0]][0:mu_vec->size[1]]) if(devicerm)
#   #pragma acc exit data delete(rec_coords[0:rec_coords_vec->size[0]][0:rec_coords_vec->size[1]]) if(devicerm)
#   #pragma acc exit data delete(src[0:src_vec->size[0]][0:src_vec->size[1]]) if(devicerm)
#   #pragma acc exit data delete(src_coords[0:src_coords_vec->size[0]][0:src_coords_vec->size[1]]) if(devicerm)
#
#   return 0;
# }
