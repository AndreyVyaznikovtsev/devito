# %%
from examples.seismic.seismic_dataset import SeismogramDataset

path = "80_61_PreReady.sgy"
dataset = SeismogramDataset(path, 'sou')
print(len(dataset))
# Out:
# 152

# %%
# print(dataset)
# Out:
# [  2.23   2.23   2.23 ... 128.86 128.86 128.86]
