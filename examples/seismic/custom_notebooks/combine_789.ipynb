# %%
import numpy as np
from scipy import stats
from scipy.ndimage import laplace, sobel, gaussian_filter, uniform_filter
from matplotlib import rc
from matplotlib import pyplot as plt
from matplotlib.ticker import MultipleLocator
from matplotlib.colors import ListedColormap
rc("font", family="serif")
rc("pgf", texsystem="pdflatex")
rc("text", usetex=True)
# rc('text.latex', unicode=True)
rc("text.latex", preamble=r"\usepackage{amssymb}")
rc("text.latex", preamble=r"\usepackage[T1,T2A]{fontenc}")
rc("text.latex", preamble=r"\usepackage[utf8]{inputenc}")
rc("text.latex", preamble=r"\usepackage[english,russian]{babel}")
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
from matplotlib.colors import ListedColormap
from examples.seismic.custom_scripts.mex_7_8.lsrtm.config import setup_model_and_geometry as setup1
from examples.seismic.custom_scripts.mex_9_8.lsrtm.config import setup_model_and_geometry as setup2
from examples.seismic.custom_scripts.mex_7_8.lsrtm.config import PATH_DATA_DSUB as PATH1
from examples.seismic.custom_scripts.mex_9_8.lsrtm.config import PATH_DATA_DSUB as PATH2
from examples.seismic.custom_scripts.mex_7_8.lsrtm.config import OUTPUT_DIRS as OUT1
from examples.seismic.custom_scripts.mex_9_8.lsrtm.config import OUTPUT_DIRS as OUT2
from examples.seismic.custom_scripts.mex_9_8.lsrtm.config import NBL
PATHMASK1 = r"/mnt/myshare/Андрей/!Аспирантура/AR_03/prestack_mute/7_8_mute_"
PATHMASK2 = r"/mnt/myshare/Андрей/!Аспирантура/AR_03/prestack_mute/9_8_mute_"

# %%
import pprint

pprint.pprint([PATH1, PATH2, OUT1, OUT2])
# Out:
# ['/home/andrey/devito-vti/examples/seismic/data/07-08_dsub.sgy',
#  '/home/andrey/devito-vti/examples/seismic/data/09-08_dsub.sgy',
#  {'adjoint_snaps': '/mnt/myshare/Андрей/!Аспирантура/mex_7_8/adjoint_snaps',
#   'forward_snaps': '/mnt/myshare/Андрей/!Аспирантура/mex_7_8/forward_snaps',
#   'gradients': '/mnt/myshare/Андрей/!Аспирантура/mex_7_8/gradients',
#   'images': '/mnt/myshare/Андрей/!Аспирантура/mex_7_8/images',
#   'results': '/mnt/myshare/Андрей/!Аспирантура/mex_7_8/logs'},
#  {'adjoint_snaps': '/mnt/myshare/Андрей/!Аспирантура/mex_9_8/adjoint_snaps',
#   'forward_snaps': '/mnt/myshare/Андрей/!Аспирантура/mex_9_8/forward_snaps',
#   'gradients': '/mnt/myshare/Андрей/!Аспирантура/mex_9_8/gradients',
#   'images': '/mnt/myshare/Андрей/!Аспирантура/mex_9_8/images',
#   'results': '/mnt/myshare/Андрей/!Аспирантура/mex_9_8/logs'}]

# %%
def process_model(velmodel, dataset, grads, invert_wells=False, scalar=1):
    grad_u0, grad_d0 = grads
    extent = [velmodel.x[0], velmodel.x[-1], velmodel.z[-1], velmodel.z[0]]

    if invert_wells:
        slope2, intercept2, _, _, _ = stats.linregress(dataset.x_coords, dataset.elevations)
        slope1, intercept1, _, _, _ = stats.linregress(dataset.opposite_x, dataset.opposite_elev)
    else:
        slope1, intercept1, _, _, _ = stats.linregress(dataset.x_coords, dataset.elevations)
        slope2, intercept2, _, _, _ = stats.linregress(dataset.opposite_x, dataset.opposite_elev)        

    # Create meshgrid for masking
    x = np.linspace(extent[0], extent[1], grad_u0.shape[0])
    z = np.linspace(extent[3], extent[2], grad_u0.shape[1])
    xx, zz = np.meshgrid(x, z, indexing='ij')

    # Create masks
    # For well1 (left boundary): points should be to the right of well1
    mask1 = xx > (zz - intercept1)/slope1 if slope1 != 0 else xx > intercept1
    # For well2 (right boundary): points should be to the left of well2
    mask2 = xx < (zz - intercept2)/slope2 if slope2 != 0 else xx < intercept2
    # Combined mask (between wells)
    between_wells_mask = mask1 & mask2

    # Apply masks to gradients and image
    grad_d0_masked = laplace(grad_d0) * between_wells_mask
    grad_u0_masked = laplace(grad_u0) * between_wells_mask
    imag0_masked = (laplace(grad_u0) - laplace(grad_d0)) * between_wells_mask

    # grad_d0_masked[grad_d0_masked==0] = np.nan
    # grad_u0_masked[grad_u0_masked==0] = np.nan
    # imag0_masked[imag0_masked==0] = np.nan

    return grad_d0_masked*scalar, grad_u0_masked*scalar, imag0_masked*scalar

# %%
model1, dataset1, velmodel1 = setup1(path_data=PATH1)
model2, dataset2, velmodel2 = setup2(path_data=PATH2)
full_grad_u0_1 = np.load(f"{OUT1['gradients']}/all_grad_u_0.npy")
full_grad_d0_1 = np.load(f"{OUT1['gradients']}/all_grad_d_0.npy")
full_grad_u0_2 = np.load(f"{OUT2['gradients']}/all_grad_u_0.npy")
full_grad_d0_2 = np.load(f"{OUT2['gradients']}/all_grad_d_0.npy")
print(full_grad_d0_1.shape)
# Out:
# Operator `initdamp` ran in 0.01 s
# Operator `initdamp` ran in 0.01 s
# (53, 241, 402)

# %%
import segyio
def get_mask(path, letter, full_grad):
    with segyio.open(path + letter + ".sgy") as f:
        x = segyio.tools.collect(f.trace[:])
    mask = np.reshape(x, (full_grad.shape[1], full_grad.shape[0], full_grad.shape[2]))
    mask = np.transpose(mask, (1, 0, 2))
    return (mask != 0).astype('float')
mask_grad_u0_1 = get_mask(PATHMASK1, 'u', full_grad_u0_1)
mask_grad_d0_1 = get_mask(PATHMASK1, 'd', full_grad_d0_1)
mask_grad_u0_2 = get_mask(PATHMASK2, 'u', full_grad_u0_2)
mask_grad_d0_2 = get_mask(PATHMASK2, 'd', full_grad_d0_2)
print(mask_grad_u0_2.shape)
print(full_grad_u0_2.shape)
# Out:
# (53, 162, 402)
# (53, 162, 402)

# %%
def equalize(full_grad):
    norm = np.linalg.norm(full_grad, axis=-1)
    return full_grad / np.expand_dims(norm, -1)

grads = [np.sum(equalize(el) * mask, axis=0) for el, mask in zip([full_grad_u0_1, full_grad_d0_1, full_grad_u0_2, full_grad_d0_2],
                                                                 [mask_grad_u0_1, mask_grad_d0_1, mask_grad_u0_2, mask_grad_d0_2]
                                                                 )]

# %%
grads1 = process_model(velmodel=velmodel1, dataset=dataset1, grads=grads[:2], invert_wells=True, scalar=1)
grads2 = process_model(velmodel=velmodel2, dataset=dataset2, grads=grads[2:])

# %%
fig, axs = plt.subplots(1, 3, figsize=(8, 4), dpi=300)
glmax = max([np.quantile(grads1[0], 0.99), np.quantile(grads2[0], 0.99)])
for grads, velmodel, model, dataset in zip([grads2, grads1], [velmodel2, velmodel1], [model2, model1], [dataset2, dataset1]):
    extent = [velmodel.x[0], velmodel.x[-1], velmodel.z[-1], velmodel.z[0]]
    grad_d0, grad_u0, imag0 = grads
    for gr, ax in zip(grads, axs):
        # Create alpha channel: 1 where gr != 0, 0 where gr == 0
        alpha = (gr != 0).astype(float).T
        
        # Apply Laplacian and display with transparency
        h = ax.imshow(gr.T,
                      vmin=-glmax, vmax=glmax,
                      cmap='gray', extent=extent,
                      alpha=alpha)  # Apply the alpha channel here
        
        # Keep the background velocity model as before
        # hh = ax.imshow(model.vp.data[NBL:-NBL, NBL:-NBL].T, 
        #              cmap='jet', vmin=0.5, vmax=5.5, alpha=0.3, extent=extent)
        
        ax.scatter(dataset.x_coords, dataset.elevations, s=1, c='cyan')
        ax.scatter(dataset.opposite_x, dataset.opposite_elev, s=1, c='cyan')

for ax in axs:
    ax.set_xlim(velmodel2.x[0], velmodel1.x[-1])
    ax.set_xlabel("Расстояние, м")
    ax.set_ylabel("Глубина, м")

plt.tight_layout()
plt.show()
