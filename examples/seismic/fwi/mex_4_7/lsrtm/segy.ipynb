# %%
from segyio import tools
from config import OUTPUT_DIRS
import numpy as np
all_grad_u0 = np.load(f"{OUTPUT_DIRS['gradients']}/all_grad_u_0.npy")
all_grad_d0 = np.load(f"{OUTPUT_DIRS['gradients']}/all_grad_d_0.npy")

# %%
tools.from_array3D("4_7_prestack_u.sgy", all_grad_u0, dt=int(1000*0.03*5))
tools.from_array3D("4_7_prestack_d.sgy", all_grad_d0, dt=int(1000*0.03*5))
